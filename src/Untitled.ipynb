# %%
cd /home/roberto/Documents/Carrera/romain_ic/wavemixing_project/src
# Out:
# /home/roberto/Documents/Carrera/romain_ic/wavemixing_project/src

# %%
import numpy as np
import matplotlib.pyplot as plt
from file_manager.visualization_preparation_tools import *

# %%
b0_input = 0.1
N = 15
Omega = 0.5
Delta = 20.0
DefaultInfo = f"N{N}_Omega{Omega}_Delta{Delta}_"
description = f"b0_{b0_input}_V_Int_On_testing_steady_state_foda_avg"
#descriptionOff = f"b0_{b0_input}_S_Int_Off_fixed__"
results_path = "../results/"
defaultangle = "25_"
angle="205"
rho_ss_parameter = "_direct"
geometric = True


phis = np.float32(np.int32(np.linspace(0,360, 21)))

# %%
experiments = np.zeros([1, len(phis)], dtype = "object")
for i in range(len(phis)):
    label_folder = results_path+DefaultInfo+description+   rho_ss_parameter + "/"
    paths_array_containing_theta_files = get_array_of_runs_dat_files(label_folder)#all runs for a given phi
    paths_array = [run_name for run_name in paths_array_containing_theta_files if "theta"  in run_name ]
    runs_txt = get_array_of_numpy_runs(paths_array, npy=True) #all runs for a given phi
    for j in range(len(experiments)):
        experiments[j][i] = runs_txt[j]
print(len(runs_txt))
# Out:
# 22

# %%
200mega =  100

300mega = 120

# %%
i=0
taulist = runs_txt[i][4]
G2 = runs_txt[i][0]
G2_single_excitation = runs_txt[i][1]
Inorm = runs_txt[i][1]
Inorm_single_excitation = runs_txt[i][2]

plt.plot(taulist,np.array(G2)/Inorm)
plt.plot(taulist,np.array(G2_single_excitation)/Inorm_single_excitation)
# Out:
# /home/roberto/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
plt.plot(np.average(runs_txt, axis = 0)[2], np.average(runs_txt, axis = 0)[0])
plt.plot(np.average(runs_txt, axis = 0)[2], np.average(runs_txt, axis = 0)[1])
# Out:
# /home/roberto/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /home/roberto/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
for i in range(len(phis)):
    plt.plot(runs_txt[i][2],runs_txt[i][0] )
# Out:
# /home/roberto/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /home/roberto/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /home/roberto/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /home/roberto/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /home/roberto/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
# ...

# %%
for i in range(len(phis)):
    plt.plot(runs_txt[i][2],runs_txt[i][1] )
# Out:
# /home/roberto/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /home/roberto/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /home/roberto/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /home/roberto/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /home/roberto/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
# ...
